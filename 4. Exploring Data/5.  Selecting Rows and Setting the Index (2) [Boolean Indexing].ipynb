# %% [markdown]
# # Boolean Indexing

# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero_5.pkl')

# %%
hero.head()
# Out:
#               gender eye color               race hair color  height  \
# name
# A-Bomb          Male    yellow              Human    No Hair     203
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Agent Bob       Male     brown              Human      Brown     178
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# A-Bomb         Marvel Comics      good   441.0         A-Bomb    False  ...
# Abomination    Marvel Comics       bad   441.0    Abomination    False  ...
# Abraxas        Marvel Comics       bad   -99.0        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad   122.0  Absorbing Man    False  ...
# Agent Bob      Marvel Comics      good    81.0      Agent Bob    False  ...
#
# ...

# %%
hero[hero['alignment'] == 'bad']
# Out:
#                gender eye color               race hair color  height  \
# name
# Abomination      Male     green  Human / Radiation    No Hair     203
# Abraxas          Male      blue      Cosmic Entity      Black     -99
# Absorbing Man    Male      blue              Human    No Hair     193
# Air-Walker       Male      blue                  -      White     188
# Ajax             Male     brown             Cyborg      Black     193
# ...               ...       ...                ...        ...     ...
# Swamp Thing      Male       red      God / Eternal    No Hair     -99
# Trigon           Male    yellow      God / Eternal      Black     -99
# Warp             Male     brown                  -      Black     173
# White Canary   Female     brown              Human      Black     -99
# Zoom             Male       red                  -      Brown     185
#
#                    publisher alignment  weight     hero names  agility  ...  \
# ...

# %%
(hero['alignment'] == 'bad') & (hero['height'] >= 200)
# Out:
# name
# A-Bomb           False
# Abomination       True
# Abraxas          False
# Absorbing Man    False
# Agent Bob        False
#                  ...
# Wildfire         False
# Wonder Girl      False
# Wonder Woman     False
# Zatanna          False
# Zoom             False
# Length: 537, dtype: bool

# %%
hero[(hero['alignment'] == 'bad') & (hero['height'] >= 200) ]
# Out:
#                 gender eye color               race hair color  height  \
# name
# Abomination       Male     green  Human / Radiation    No Hair     203
# Apocalypse        Male       red             Mutant      Black     213
# Bloodaxe        Female      blue              Human      Brown     218
# Doctor Doom       Male     brown              Human      Brown     201
# Doctor Doom II    Male     brown                  -      Brown     201
# Frenzy          Female     brown                  -      Black     211
# Hela            Female     green          Asgardian      Black     213
# Lizard            Male       red              Human    No Hair     203
# MODOK             Male     white             Cyborg     Brownn     366
# Onslaught         Male       red             Mutant    No Hair     305
# Scorpion          Male     brown              Human      Brown     211
# Thanos            Male       red            Eternal    No Hair     201
# ...

# %%
hero[(hero['hair color']=='No Hair') | (hero['hair color']=='Blond')]
# Out:
#                gender eye color               race hair color  height  \
# name
# A-Bomb           Male    yellow              Human    No Hair     203
# Abomination      Male     green  Human / Radiation    No Hair     203
# Absorbing Man    Male      blue              Human    No Hair     193
# Angel            Male      blue                  -      Blond     183
# Annihilus        Male     green                  -    No Hair     180
# ...               ...       ...                ...        ...     ...
# Steel            Male     brown                  -    No Hair     201
# Supergirl      Female      blue         Kryptonian      Blond     165
# Swamp Thing      Male       red      God / Eternal    No Hair     -99
# Trickster        Male      blue              Human      Blond     183
# Wonder Girl    Female      blue           Demi-God      Blond     165
#
#                    publisher alignment  weight     hero names  agility  ...  \
# ...

# %%
hero['hair color'].isin(['No Hair','Blond'])
# Out:
# name
# A-Bomb            True
# Abomination       True
# Abraxas          False
# Absorbing Man     True
# Agent Bob        False
#                  ...
# Wildfire         False
# Wonder Girl       True
# Wonder Woman     False
# Zatanna          False
# Zoom             False
# Name: hair color, Length: 537, dtype: bool

# %%
hero[hero['hair color'].isin(['No Hair','Blond'])]
# Out:
#                gender eye color               race hair color  height  \
# name
# A-Bomb           Male    yellow              Human    No Hair     203
# Abomination      Male     green  Human / Radiation    No Hair     203
# Absorbing Man    Male      blue              Human    No Hair     193
# Angel            Male      blue                  -      Blond     183
# Annihilus        Male     green                  -    No Hair     180
# ...               ...       ...                ...        ...     ...
# Steel            Male     brown                  -    No Hair     201
# Supergirl      Female      blue         Kryptonian      Blond     165
# Swamp Thing      Male       red      God / Eternal    No Hair     -99
# Trickster        Male      blue              Human      Blond     183
# Wonder Girl    Female      blue           Demi-God      Blond     165
#
#                    publisher alignment  weight     hero names  agility  ...  \
# ...

# %%
hero[hero['alignment'].isin(['good','bad'])]
# Out:
#                gender eye color               race hair color  height  \
# name
# A-Bomb           Male    yellow              Human    No Hair     203
# Abomination      Male     green  Human / Radiation    No Hair     203
# Abraxas          Male      blue      Cosmic Entity      Black     -99
# Absorbing Man    Male      blue              Human    No Hair     193
# Agent Bob        Male     brown              Human      Brown     178
# ...               ...       ...                ...        ...     ...
# Wildfire         Male         -                  -          -     -99
# Wonder Girl    Female      blue           Demi-God      Blond     165
# Wonder Woman   Female      blue             Amazon      Black     183
# Zatanna        Female      blue              Human      Black     170
# Zoom             Male       red                  -      Brown     185
#
#                    publisher alignment  weight     hero names  agility  ...  \
# ...

# %%
hero[~hero['alignment'].isin(['good','bad'])]
# Out:
#                  gender eye color               race hair color  height  \
# name
# Anti-Venom         Male      blue           Symbiote      Blond     229
# Blackwulf          Male       red              Alien      White     188
# Copycat          Female       red             Mutant      White     183
# Deadpool           Male     brown             Mutant    No Hair     188
# Galactus           Male     black      Cosmic Entity      Black     876
# Gladiator          Male      blue          Strontian       Blue     198
# Juggernaut         Male      blue              Human        Red     287
# Living Tribunal       -      blue      Cosmic Entity    No Hair     -99
# One-Above-All         -         -      Cosmic Entity          -     -99
# Red Hulk           Male    yellow  Human / Radiation      Black     213
# Sandman            Male     brown              Human      Brown     185
# Sentry             Male      blue             Mutant      Blond     188
# ...

# %% [markdown]
# # Summary

# %% [markdown]
# <img src="loc_method.jpg" style="width:400px;height:200px"/>

# %% [markdown]
# # ---------------------------------------------------------------------

# %% [markdown]
# <img src="iloc_method.jpg" style="width:400px;height:200px"/>

# %% [markdown]
# # ---------------------------------------------------------------------

# %% [markdown]
# <img src="bool_method.jpg" style="width:400px;height:200px"/>

# %%
hero.index
# Out:
# Index(['A-Bomb', 'Abomination', 'Abraxas', 'Absorbing Man', 'Agent Bob',
#        'Agent Zero', 'Air-Walker', 'Ajax', 'Ammo', 'Angel',
#        ...
#        'Triplicate Girl', 'Vibe', 'Vixen', 'Warp', 'White Canary', 'Wildfire',
#        'Wonder Girl', 'Wonder Woman', 'Zatanna', 'Zoom'],
#       dtype='string', name='name', length=537)

# %%
hero = hero.reset_index()

# %%
hero.head()
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
# 4      Agent Bob   Male     brown              Human      Brown     178
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good   441.0         A-Bomb  ...         False
# 1  Marvel Comics       bad   441.0    Abomination  ...         False
# 2  Marvel Comics       bad   -99.0        Abraxas  ...         False
# 3  Marvel Comics       bad   122.0  Absorbing Man  ...         False
# 4  Marvel Comics      good    81.0      Agent Bob  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# ...

# %% [markdown]
# ### find hero_neutral

# %%
hero_neutral = hero[hero['alignment']=='neutral']

# %%
hero_neutral.head()
# Out:
#            name  gender eye color           race hair color  height  \
# 83      Copycat  Female       red         Mutant      White     183
# 94     Deadpool    Male     brown         Mutant    No Hair     188
# 127    Galactus    Male     black  Cosmic Entity      Black     876
# 133   Gladiator    Male      blue      Strontian       Blue     198
# 171  Juggernaut    Male      blue          Human        Red     287
#
#          publisher alignment  weight  hero names  ...  web creation  \
# 83   Marvel Comics   neutral    67.0     Copycat  ...         False
# 94   Marvel Comics   neutral    95.0    Deadpool  ...         False
# 127  Marvel Comics   neutral    16.0    Galactus  ...         False
# 133  Marvel Comics   neutral   268.0   Gladiator  ...         False
# 171  Marvel Comics   neutral   855.0  Juggernaut  ...         False
#
#      reality warping  odin force  symbiote costume  speed force  \
# 83             False       False             False        False
# ...

# %%
hero_neutral.loc[83]
# Out:
# name                     Copycat
# gender                    Female
# eye color                    red
# race                      Mutant
# hair color                 White
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: 83, Length: 177, dtype: object

# %%
hero_neutral.iloc[0]
# Out:
# name                     Copycat
# gender                    Female
# eye color                    red
# race                      Mutant
# hair color                 White
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: 83, Length: 177, dtype: object

# %%
hero_neutral.loc[83:127]
# Out:
#          name  gender eye color           race hair color  height  \
# 83    Copycat  Female       red         Mutant      White     183
# 94   Deadpool    Male     brown         Mutant    No Hair     188
# 127  Galactus    Male     black  Cosmic Entity      Black     876
#
#          publisher alignment  weight hero names  ...  web creation  \
# 83   Marvel Comics   neutral    67.0    Copycat  ...         False
# 94   Marvel Comics   neutral    95.0   Deadpool  ...         False
# 127  Marvel Comics   neutral    16.0   Galactus  ...         False
#
#      reality warping  odin force  symbiote costume  speed force  \
# 83             False       False             False        False
# 94             False       False             False        False
# 127            False       False             False        False
#
#      phoenix force  molecular dissipation  vision - cryo  omnipresent  \
# 83           False                  False          False        False
# ...

# %%
hero_neutral.iloc[0:3]
# Out:
#          name  gender eye color           race hair color  height  \
# 83    Copycat  Female       red         Mutant      White     183
# 94   Deadpool    Male     brown         Mutant    No Hair     188
# 127  Galactus    Male     black  Cosmic Entity      Black     876
#
#          publisher alignment  weight hero names  ...  web creation  \
# 83   Marvel Comics   neutral    67.0    Copycat  ...         False
# 94   Marvel Comics   neutral    95.0   Deadpool  ...         False
# 127  Marvel Comics   neutral    16.0   Galactus  ...         False
#
#      reality warping  odin force  symbiote costume  speed force  \
# 83             False       False             False        False
# 94             False       False             False        False
# 127            False       False             False        False
#
#      phoenix force  molecular dissipation  vision - cryo  omnipresent  \
# 83           False                  False          False        False
# ...
