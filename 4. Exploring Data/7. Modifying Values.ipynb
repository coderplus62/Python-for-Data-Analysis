# %% [markdown]
# # Modifying Values

# %% [markdown]
# <img src='modify_v.jpg' style='widht:300px;height:270px'>

# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero_4.pkl')

# %%
hero.head(10)
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
# 4      Agent Bob   Male     brown              Human      Brown     178
# 5     Agent Zero   Male         -                  -          -     191
# 6     Air-Walker   Male      blue                  -      White     188
# 7           Ajax   Male     brown             Cyborg      Black     193
# 8           Ammo   Male     brown              Human      Black     188
# 9          Angel   Male      blue                  -      Blond     183
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good   441.0         A-Bomb  ...         False
# ...

# %%
hero
# Out:
#               name  gender eye color               race hair color  height  \
# 0           A-Bomb    Male    yellow              Human    No Hair     203
# 1      Abomination    Male     green  Human / Radiation    No Hair     203
# 2          Abraxas    Male      blue      Cosmic Entity      Black     -99
# 3    Absorbing Man    Male      blue              Human    No Hair     193
# 4        Agent Bob    Male     brown              Human      Brown     178
# ..             ...     ...       ...                ...        ...     ...
# 532       Wildfire    Male         -                  -          -     -99
# 533    Wonder Girl  Female      blue           Demi-God      Blond     165
# 534   Wonder Woman  Female      blue             Amazon      Black     183
# 535        Zatanna  Female      blue              Human      Black     170
# 536           Zoom    Male       red                  -      Brown     185
#
# ...

# %%
hero[hero['race']=='-']
# Out:
#                 name  gender eye color race hair color  height      publisher  \
# 5         Agent Zero    Male         -    -          -     191  Marvel Comics
# 6         Air-Walker    Male      blue    -      White     188  Marvel Comics
# 9              Angel    Male      blue    -      Blond     183  Marvel Comics
# 11   Angel Salvadore  Female     brown    -      Black     163  Marvel Comics
# 12         Annihilus    Male     green    -    No Hair     180  Marvel Comics
# ..               ...     ...       ...  ...        ...     ...            ...
# 519         Superboy    Male      blue    -      Black     170      DC Comics
# 527  Triplicate Girl  Female    purple    -      Brown     168      DC Comics
# 530             Warp    Male     brown    -      Black     173      DC Comics
# 532         Wildfire    Male         -    -          -     -99      DC Comics
# 536             Zoom    Male       red    -      Brown     185      DC Comics
#
# ...

# %% [markdown]
# ## Changing data entry

# %%
hero.loc[5,'race']='Unknown'

# %%
hero[hero['race']=='-']
# Out:
#                 name  gender eye color race hair color  height      publisher  \
# 6         Air-Walker    Male      blue    -      White     188  Marvel Comics
# 9              Angel    Male      blue    -      Blond     183  Marvel Comics
# 11   Angel Salvadore  Female     brown    -      Black     163  Marvel Comics
# 12         Annihilus    Male     green    -    No Hair     180  Marvel Comics
# 19          Arclight  Female    violet    -     Purple     173  Marvel Comics
# ..               ...     ...       ...  ...        ...     ...            ...
# 519         Superboy    Male      blue    -      Black     170      DC Comics
# 527  Triplicate Girl  Female    purple    -      Brown     168      DC Comics
# 530             Warp    Male     brown    -      Black     173      DC Comics
# 532         Wildfire    Male         -    -          -     -99      DC Comics
# 536             Zoom    Male       red    -      Brown     185      DC Comics
#
# ...

# %%
hero.iloc[6,3]='Unknown'

# %%
hero['race']=='-'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 532     True
# 533    False
# 534    False
# 535    False
# 536     True
# Name: race, Length: 537, dtype: boolean

# %% [markdown]
# ## Change all data in race column from '-' to 'Unknown'

# %%
hero.loc[hero['race']=='-','race'] = 'Unknown'

# %%
hero[hero['race']=='Unknown']
# Out:
#            name  gender eye color     race hair color  height      publisher  \
# 5    Agent Zero    Male         -  Unknown          -     191  Marvel Comics
# 6    Air-Walker    Male      blue  Unknown      White     188  Marvel Comics
# 9       Unknown    Male      blue  Unknown      Blond     183  Marvel Comics
# 11      Unknown  Female     brown  Unknown      Black     163  Marvel Comics
# 12      Unknown    Male     green  Unknown    No Hair     180  Marvel Comics
# ..          ...     ...       ...      ...        ...     ...            ...
# 519     Unknown    Male      blue  Unknown      Black     170      DC Comics
# 527     Unknown  Female    purple  Unknown      Brown     168      DC Comics
# 530     Unknown    Male     brown  Unknown      Black     173      DC Comics
# 532     Unknown    Male         -  Unknown          -     -99      DC Comics
# 536     Unknown    Male       red  Unknown      Brown     185      DC Comics
#
# ...

# %%
hero.tail()
# Out:
#              name  gender eye color      race hair color  height  publisher  \
# 532       Unknown    Male         -   Unknown          -     -99  DC Comics
# 533   Wonder Girl  Female      blue  Demi-God      Blond     165  DC Comics
# 534  Wonder Woman  Female      blue    Amazon      Black     183  DC Comics
# 535       Zatanna  Female      blue     Human      Black     170  DC Comics
# 536       Unknown    Male       red   Unknown      Brown     185  DC Comics
#
#     alignment  weight    hero names  ...  web creation  reality warping  \
# 532      good     NaN      Wildfire  ...         False            False
# 533      good    51.0   Wonder Girl  ...         False            False
# 534      good    74.0  Wonder Woman  ...         False            False
# 535      good    57.0       Zatanna  ...         False            False
# 536       bad    81.0          Zoom  ...         False            False
#
#      odin force  symbiote costume  speed force  phoenix force  \
# ...

# %% [markdown]
# ## Adding new row

# %%
hero.loc[1000] = hero.loc[534]

# %%
hero.tail()
# Out:
#               name  gender eye color      race hair color    height  \
# 533    Wonder Girl  Female      blue  Demi-God      Blond  5.413386
# 534   Wonder Woman  Female      blue    Amazon      Black  6.003937
# 535        Zatanna  Female      blue     Human      Black  5.577428
# 536        Unknown    Male       red   Unknown      Brown  6.069554
# 1000  Wonder Woman  Female      blue    Amazon      Black  6.003937
#
#       publisher alignment  weight    hero names  ...  web creation  \
# 533   DC Comics      good    51.0   Wonder Girl  ...         False
# 534   DC Comics      good    74.0  Wonder Woman  ...         False
# 535   DC Comics      good    57.0       Zatanna  ...         False
# 536   DC Comics       bad    81.0          Zoom  ...         False
# 1000  DC Comics      good    74.0  Wonder Woman  ...         False
#
#       reality warping  odin force  symbiote costume  speed force  \
# 533             False       False             False        False
# ...

# %%
hero.iloc[536] = hero.iloc[535]

# %%
hero.tail()
# Out:
#               name  gender eye color      race hair color    height  \
# 533    Wonder Girl  Female      blue  Demi-God      Blond  5.413386
# 534   Wonder Woman  Female      blue    Amazon      Black  6.003937
# 535        Zatanna  Female      blue     Human      Black  5.577428
# 536        Zatanna  Female      blue     Human      Black  5.577428
# 1000  Wonder Woman  Female      blue    Amazon      Black  6.003937
#
#       publisher alignment  weight    hero names  ...  web creation  \
# 533   DC Comics      good    51.0   Wonder Girl  ...         False
# 534   DC Comics      good    74.0  Wonder Woman  ...         False
# 535   DC Comics      good    57.0       Zatanna  ...         False
# 536   DC Comics      good    57.0       Zatanna  ...         False
# 1000  DC Comics      good    74.0  Wonder Woman  ...         False
#
#       reality warping  odin force  symbiote costume  speed force  \
# 533             False       False             False        False
# ...

# %% [markdown]
# ## Update height from cm to feet

# %%
hero['height']*0.0328084
# Out:
# 0      6.660105
# 1      6.660105
# 2     -3.248032
# 3      6.332021
# 4      5.839895
#          ...
# 532   -3.248032
# 533    5.413386
# 534    6.003937
# 535    5.577428
# 536    6.069554
# Name: height, Length: 537, dtype: float64

# %%
hero
# Out:
#               name  gender eye color               race hair color  height  \
# 0           A-Bomb    Male    yellow              Human    No Hair     203
# 1      Abomination    Male     green  Human / Radiation    No Hair     203
# 2          Abraxas    Male      blue      Cosmic Entity      Black     -99
# 3    Absorbing Man    Male      blue              Human    No Hair     193
# 4        Agent Bob    Male     brown              Human      Brown     178
# ..             ...     ...       ...                ...        ...     ...
# 532        Unknown    Male         -            Unknown          -     -99
# 533    Wonder Girl  Female      blue           Demi-God      Blond     165
# 534   Wonder Woman  Female      blue             Amazon      Black     183
# 535        Zatanna  Female      blue              Human      Black     170
# 536        Unknown    Male       red            Unknown      Brown     185
#
# ...

# %%
hero['height'] = hero['height']*0.0328084

# %%
hero
# Out:
#               name  gender eye color               race hair color    height  \
# 0           A-Bomb    Male    yellow              Human    No Hair  6.660105
# 1      Abomination    Male     green  Human / Radiation    No Hair  6.660105
# 2          Abraxas    Male      blue      Cosmic Entity      Black -3.248032
# 3    Absorbing Man    Male      blue              Human    No Hair  6.332021
# 4        Agent Bob    Male     brown              Human      Brown  5.839895
# ..             ...     ...       ...                ...        ...       ...
# 532        Unknown    Male         -            Unknown          - -3.248032
# 533    Wonder Girl  Female      blue           Demi-God      Blond  5.413386
# 534   Wonder Woman  Female      blue             Amazon      Black  6.003937
# 535        Zatanna  Female      blue              Human      Black  5.577428
# 536        Unknown    Male       red            Unknown      Brown  6.069554
#
# ...

# %%
hero.select_dtypes(include='number')
# Out:
#         height  weight
# 0     6.660105   441.0
# 1     6.660105   441.0
# 2    -3.248032   -99.0
# 3     6.332021   122.0
# 4     5.839895    81.0
# ...        ...     ...
# 533   5.413386    51.0
# 534   6.003937    74.0
# 535   5.577428    57.0
# 536   5.577428    57.0
# 1000  6.003937    74.0
#
# [538 rows x 2 columns]

# %%
hero.select_dtypes(include='number').columns
# Out:
# Index(['height', 'weight'], dtype='object')

# %%
numeric_cols = hero.select_dtypes(include='number').columns

# %%
hero[numeric_cols]
# Out:
#         height  weight
# 0     6.660105   441.0
# 1     6.660105   441.0
# 2    -3.248032   -99.0
# 3     6.332021   122.0
# 4     5.839895    81.0
# ...        ...     ...
# 533   5.413386    51.0
# 534   6.003937    74.0
# 535   5.577428    57.0
# 536   5.577428    57.0
# 1000  6.003937    74.0
#
# [538 rows x 2 columns]

# %%
hero[numeric_cols] = hero[numeric_cols]*100

# %%
hero[numeric_cols]
# Out:
#          height   weight
# 0     666.01052  44100.0
# 1     666.01052  44100.0
# 2    -324.80316  -9900.0
# 3     633.20212  12200.0
# 4     583.98952   8100.0
# ...         ...      ...
# 533   541.33860   5100.0
# 534   600.39372   7400.0
# 535   557.74280   5700.0
# 536   557.74280   5700.0
# 1000  600.39372   7400.0
#
# [538 rows x 2 columns]

# %%
hero[numeric_cols] = hero[numeric_cols]/100

# %%
hero[numeric_cols]
# Out:
#         height  weight
# 0     6.660105   441.0
# 1     6.660105   441.0
# 2    -3.248032   -99.0
# 3     6.332021   122.0
# 4     5.839895    81.0
# ...        ...     ...
# 533   5.413386    51.0
# 534   6.003937    74.0
# 535   5.577428    57.0
# 536   5.577428    57.0
# 1000  6.003937    74.0
#
# [538 rows x 2 columns]

# %%
# bmi = weight(kg) / [height(m)]^2
hero['bmi'] = hero['weight']/(hero['height']/3.28084)**2

# %%
hero.columns
# Out:
# Index(['name', 'gender', 'eye color', 'race', 'hair color', 'height',
#        'publisher', 'alignment', 'weight', 'hero names',
#        ...
#        'reality warping', 'odin force', 'symbiote costume', 'speed force',
#        'phoenix force', 'molecular dissipation', 'vision - cryo',
#        'omnipresent', 'omniscient', 'bmi'],
#       dtype='object', length=178)

# %%
hero.head()
# Out:
#             name gender eye color               race hair color    height  \
# 0         A-Bomb   Male    yellow              Human    No Hair  6.660105
# 1    Abomination   Male     green  Human / Radiation    No Hair  6.660105
# 2        Abraxas   Male      blue      Cosmic Entity      Black -3.248032
# 3  Absorbing Man   Male      blue              Human    No Hair  6.332021
# 4      Agent Bob   Male     brown              Human      Brown  5.839895
#
#        publisher alignment  weight     hero names  ...  reality warping  \
# 0  Marvel Comics      good   441.0         A-Bomb  ...            False
# 1  Marvel Comics       bad   441.0    Abomination  ...            False
# 2  Marvel Comics       bad   -99.0        Abraxas  ...            False
# 3  Marvel Comics       bad   122.0  Absorbing Man  ...            False
# 4  Marvel Comics      good    81.0      Agent Bob  ...            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# ...

# %%
hero.to_pickle('hero_8.pkl')
