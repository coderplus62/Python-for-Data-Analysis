# %% [markdown]
# # Subsetting Both Rows and Columns

# %% [markdown]
# <img src='subset_rc.jpg' style='width:300px;height:250px'/>

# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero_4.pkl')

# %%
hero.head()
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
# 4      Agent Bob   Male     brown              Human      Brown     178
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good   441.0         A-Bomb  ...         False
# 1  Marvel Comics       bad   441.0    Abomination  ...         False
# 2  Marvel Comics       bad   -99.0        Abraxas  ...         False
# 3  Marvel Comics       bad   122.0  Absorbing Man  ...         False
# 4  Marvel Comics      good    81.0      Agent Bob  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 0            False       False             False        False          False
# 1            False       False             False        False          False
# 2            False       False             False        False          False
# 3            False       False             False        False          False
# 4            False       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 177 columns]

# %%
hero.loc[0,:]
# Out:
# name                      A-Bomb
# gender                      Male
# eye color                 yellow
# race                       Human
# hair color               No Hair
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: 0, Length: 177, dtype: object

# %%
hero.loc[0,'race']
# Out:
# 'Human'

# %%
hero.iloc[0,3]
# Out:
# 'Human'

# %%
hero.loc[2:4,'race':'height']
# Out:
#             race hair color  height
# 2  Cosmic Entity      Black     -99
# 3          Human    No Hair     193
# 4          Human      Brown     178

# %%
hero.iloc[2:5,3:6]
# Out:
#             race hair color  height
# 2  Cosmic Entity      Black     -99
# 3          Human    No Hair     193
# 4          Human      Brown     178

# %%
hero.loc[10:20,['hero names','super strength','flight','super speed']]
# Out:
#          hero names  super strength  flight  super speed
# 10       Angel Dust            True   False         True
# 11  Angel Salvadore           False    True        False
# 12        Annihilus            True    True         True
# 13          Ant-Man           False   False        False
# 14       Ant-Man II            True   False        False
# 15       Anti-Venom            True   False        False
# 16       Apocalypse            True    True         True
# 17          Arachne            True   False         True
# 18        Archangel            True    True        False
# 19         Arclight            True   False        False
# 20           Ardina            True    True         True

# %%
hero.iloc[10:21,[9,27,18,40]]
# Out:
#          hero names  super strength  flight  super speed
# 10       Angel Dust            True   False         True
# 11  Angel Salvadore           False    True        False
# 12        Annihilus            True    True         True
# 13          Ant-Man           False   False        False
# 14       Ant-Man II            True   False        False
# 15       Anti-Venom            True   False        False
# 16       Apocalypse            True    True         True
# 17          Arachne            True   False         True
# 18        Archangel            True    True        False
# 19         Arclight            True   False        False
# 20           Ardina            True    True         True

# %%
# hero[hero['flight']==True,'name']
# it does not work; instead, using eiter loc or iloc

# %%
hero.loc[hero['flight']==True,'name']
# Out:
# 2              Abraxas
# 6           Air-Walker
# 9                Angel
# 11     Angel Salvadore
# 12           Annihilus
#             ...
# 529              Vixen
# 530               Warp
# 532           Wildfire
# 533        Wonder Girl
# 534       Wonder Woman
# Name: name, Length: 197, dtype: string

# %%
hero.iloc[(hero['flight']==True).values,0]
# Out:
# 2              Abraxas
# 6           Air-Walker
# 9                Angel
# 11     Angel Salvadore
# 12           Annihilus
#             ...
# 529              Vixen
# 530               Warp
# 532           Wildfire
# 533        Wonder Girl
# 534       Wonder Woman
# Name: name, Length: 197, dtype: string

# %% [markdown]
# # Summary

# %% [markdown]
# <img src='sum_subset_df.jpg'>

# %%
hero[(hero['alignment'] == 'bad') & (hero['height'] >= 200) & (hero['publisher'] == 'Marvel Comics')]
# Out:
#                name  gender eye color               race hair color  height  \
# 1       Abomination    Male     green  Human / Radiation    No Hair     203
# 16       Apocalypse    Male       red             Mutant      Black     213
# 58         Bloodaxe  Female      blue              Human      Brown     218
# 100     Doctor Doom    Male     brown              Human      Brown     201
# 101  Doctor Doom II    Male     brown                  -      Brown     201
# 125          Frenzy  Female     brown                  -      Black     211
# 145            Hela  Female     green          Asgardian      Black     213
# 185          Lizard    Male       red              Human    No Hair     203
# 209           MODOK    Male     white             Cyborg     Brownn     366
# 233       Onslaught    Male       red             Mutant    No Hair     305
# 261        Scorpion    Male     brown              Human      Brown     211
# 298          Thanos    Male       red            Eternal    No Hair     201
# 314          Ultron    Male       red            Android          -     206
# 320       Venom III    Male     brown           Symbiote      Brown     229
#
#          publisher alignment  weight      hero names  ...  web creation  \
# 1    Marvel Comics       bad   441.0     Abomination  ...         False
# 16   Marvel Comics       bad   135.0      Apocalypse  ...         False
# 58   Marvel Comics       bad   495.0        Bloodaxe  ...         False
# 100  Marvel Comics       bad   187.0     Doctor Doom  ...         False
# 101  Marvel Comics       bad   132.0  Doctor Doom II  ...         False
# 125  Marvel Comics       bad   104.0          Frenzy  ...         False
# 145  Marvel Comics       bad   225.0            Hela  ...         False
# 185  Marvel Comics       bad   230.0          Lizard  ...         False
# 209  Marvel Comics       bad   338.0           MODOK  ...         False
# 233  Marvel Comics       bad   405.0       Onslaught  ...         False
# 261  Marvel Comics       bad   310.0        Scorpion  ...         False
# 298  Marvel Comics       bad   443.0          Thanos  ...         False
# 314  Marvel Comics       bad   331.0          Ultron  ...         False
# 320  Marvel Comics       bad   334.0       Venom III  ...         False
#
#      reality warping  odin force  symbiote costume  speed force  \
# 1              False       False             False        False
# 16             False       False             False        False
# 58             False       False             False        False
# 100            False       False             False        False
# 101            False       False             False        False
# 125            False       False             False        False
# 145            False       False             False        False
# 185            False       False             False        False
# 209            False       False             False        False
# 233             True       False             False        False
# 261            False       False             False        False
# 298             True       False             False        False
# 314            False       False             False        False
# 320            False       False              True        False
#
#      phoenix force  molecular dissipation  vision - cryo  omnipresent  \
# 1            False                  False          False        False
# 16           False                  False          False        False
# 58           False                  False          False        False
# 100          False                  False          False        False
# 101          False                  False          False        False
# 125          False                  False          False        False
# 145          False                  False          False        False
# 185          False                  False          False        False
# 209          False                  False          False        False
# 233          False                  False          False        False
# 261          False                  False          False        False
# 298          False                  False          False        False
# 314          False                  False          False        False
# 320          False                  False          False        False
#
#      omniscient
# 1         False
# 16        False
# 58        False
# 100       False
# 101       False
# 125       False
# 145       False
# 185       False
# 209       False
# 233       False
# 261       False
# 298       False
# 314       False
# 320       False
#
# [14 rows x 177 columns]

# %%
hero_new = hero[:100]

# %%
hero_new[(hero_new['alignment'] == 'bad') & (hero_new['height'] >= 200)]
# Out:
#            name  gender eye color               race hair color  height  \
# 1   Abomination    Male     green  Human / Radiation    No Hair     203
# 16   Apocalypse    Male       red             Mutant      Black     213
# 58     Bloodaxe  Female      blue              Human      Brown     218
#
#         publisher alignment  weight   hero names  ...  web creation  \
# 1   Marvel Comics       bad   441.0  Abomination  ...         False
# 16  Marvel Comics       bad   135.0   Apocalypse  ...         False
# 58  Marvel Comics       bad   495.0     Bloodaxe  ...         False
#
#     reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 1             False       False             False        False          False
# 16            False       False             False        False          False
# 58            False       False             False        False          False
#
#     molecular dissipation  vision - cryo  omnipresent  omniscient
# 1                   False          False        False       False
# 16                  False          False        False       False
# 58                  False          False        False       False
#
# [3 rows x 177 columns]

# %%
hero_new = hero[:100][(hero_new['alignment'] == 'bad') & (hero_new['height'] >= 200)][['name','race']]

# %%
hero_new
# Out:
#            name               race
# 1   Abomination  Human / Radiation
# 16   Apocalypse             Mutant
# 58     Bloodaxe              Human
