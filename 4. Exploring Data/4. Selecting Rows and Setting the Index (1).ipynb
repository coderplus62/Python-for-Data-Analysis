# %% [markdown]
# # Selecting Rows and Setting the Index (1)

# %% [markdown]
# <img src="selecting_row.jpg" style="width:300px;height:300px"/>

# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero_4.pkl')

# %%
hero.head()
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
# 4      Agent Bob   Male     brown              Human      Brown     178
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good   441.0         A-Bomb  ...         False
# 1  Marvel Comics       bad   441.0    Abomination  ...         False
# 2  Marvel Comics       bad   -99.0        Abraxas  ...         False
# 3  Marvel Comics       bad   122.0  Absorbing Man  ...         False
# 4  Marvel Comics      good    81.0      Agent Bob  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# ...

# %% [markdown]
# ## Using .loc

# %%
hero.loc[6:10]
# Out:
#           name  gender eye color    race hair color  height      publisher  \
# 6   Air-Walker    Male      blue       -      White     188  Marvel Comics
# 7         Ajax    Male     brown  Cyborg      Black     193  Marvel Comics
# 8         Ammo    Male     brown   Human      Black     188  Marvel Comics
# 9        Angel    Male      blue       -      Blond     183  Marvel Comics
# 10  Angel Dust  Female    yellow  Mutant      Black     165  Marvel Comics
#
#    alignment  weight  hero names  ...  web creation  reality warping  \
# 6        bad   108.0  Air-Walker  ...         False            False
# 7        bad    90.0        Ajax  ...         False            False
# 8        bad   101.0        Ammo  ...         False            False
# 9       good    68.0       Angel  ...         False            False
# 10      good    57.0  Angel Dust  ...         False            False
#
#     odin force  symbiote costume  speed force  phoenix force  \
# ...

# %%
hero = hero.set_index('name')

# %%
hero.head()
# Out:
#               gender eye color               race hair color  height  \
# name
# A-Bomb          Male    yellow              Human    No Hair     203
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Agent Bob       Male     brown              Human      Brown     178
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# A-Bomb         Marvel Comics      good   441.0         A-Bomb    False  ...
# Abomination    Marvel Comics       bad   441.0    Abomination    False  ...
# Abraxas        Marvel Comics       bad   -99.0        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad   122.0  Absorbing Man    False  ...
# Agent Bob      Marvel Comics      good    81.0      Agent Bob    False  ...
#
# ...

# %%
hero.index
# Out:
# Index(['A-Bomb', 'Abomination', 'Abraxas', 'Absorbing Man', 'Agent Bob',
#        'Agent Zero', 'Air-Walker', 'Ajax', 'Ammo', 'Angel',
#        ...
#        'Triplicate Girl', 'Vibe', 'Vixen', 'Warp', 'White Canary', 'Wildfire',
#        'Wonder Girl', 'Wonder Woman', 'Zatanna', 'Zoom'],
#       dtype='string', name='name', length=537)

# %%
hero.loc['Superman']
# Out:
# gender                         Male
# eye color                      blue
# race                     Kryptonian
# hair color                    Black
# height                          191
#                             ...
# phoenix force                 False
# molecular dissipation         False
# vision - cryo                 False
# omnipresent                   False
# omniscient                    False
# Name: Superman, Length: 176, dtype: object

# %%
hero.loc['Superman':'Wonder Woman']
# Out:
#                  gender eye color           race hair color  height  \
# name
# Superman           Male      blue     Kryptonian      Black     191
# Swamp Thing        Male       red  God / Eternal    No Hair     -99
# The Comedian       Male     brown          Human      Black     188
# Trickster          Male      blue          Human      Blond     183
# Trigon             Male    yellow  God / Eternal      Black     -99
# Triplicate Girl  Female    purple              -      Brown     168
# Vibe               Male     brown          Human      Black     178
# Vixen            Female     amber          Human      Black     175
# Warp               Male     brown              -      Black     173
# White Canary     Female     brown          Human      Black     -99
# Wildfire           Male         -              -          -     -99
# Wonder Girl      Female      blue       Demi-God      Blond     165
# Wonder Woman     Female      blue         Amazon      Black     183
#
# ...

# %%
hero.loc[['Spider-Man','Wonder Woman','Superman']]
# Out:
#               gender eye color        race hair color  height      publisher  \
# name
# Spider-Man      Male     hazel       Human      Brown     178  Marvel Comics
# Spider-Man         -       red       Human      Brown     178  Marvel Comics
# Spider-Man      Male     brown       Human      Black     157  Marvel Comics
# Wonder Woman  Female      blue      Amazon      Black     183      DC Comics
# Superman        Male      blue  Kryptonian      Black     191      DC Comics
#
#              alignment  weight    hero names  agility  ...  web creation  \
# name                                                   ...
# Spider-Man        good    74.0    Spider-Man     True  ...          True
# Spider-Man        good    77.0    Spider-Man     True  ...          True
# Spider-Man        good    56.0    Spider-Man     True  ...          True
# Wonder Woman      good    74.0  Wonder Woman    False  ...         False
# Superman          good   101.0      Superman     True  ...         False
# ...

# %% [markdown]
# ## Using .iloc

# %%
hero.head()
# Out:
#               gender eye color               race hair color  height  \
# name
# A-Bomb          Male    yellow              Human    No Hair     203
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Agent Bob       Male     brown              Human      Brown     178
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# A-Bomb         Marvel Comics      good   441.0         A-Bomb    False  ...
# Abomination    Marvel Comics       bad   441.0    Abomination    False  ...
# Abraxas        Marvel Comics       bad   -99.0        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad   122.0  Absorbing Man    False  ...
# Agent Bob      Marvel Comics      good    81.0      Agent Bob    False  ...
#
# ...

# %%
hero.iloc[0]
# Out:
# gender                      Male
# eye color                 yellow
# race                       Human
# hair color               No Hair
# height                       203
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: A-Bomb, Length: 176, dtype: object

# %% [raw]
# hero.iloc[1:4]

# %%
hero.iloc[[4,1,8]]
# Out:
#             gender eye color               race hair color  height  \
# name
# Agent Bob     Male     brown              Human      Brown     178
# Abomination   Male     green  Human / Radiation    No Hair     203
# Ammo          Male     brown              Human      Black     188
#
#                  publisher alignment  weight   hero names  agility  ...  \
# name                                                                ...
# Agent Bob    Marvel Comics      good    81.0    Agent Bob    False  ...
# Abomination  Marvel Comics       bad   441.0  Abomination    False  ...
# Ammo         Marvel Comics       bad   101.0         Ammo    False  ...
#
#              web creation  reality warping  odin force  symbiote costume  \
# name
# Agent Bob           False            False       False             False
# Abomination         False            False       False             False
# Ammo                False            False       False             False
#
# ...

# %%
hero['alignment']
# Out:
# name
# A-Bomb           good
# Abomination       bad
# Abraxas           bad
# Absorbing Man     bad
# Agent Bob        good
#                  ...
# Wildfire         good
# Wonder Girl      good
# Wonder Woman     good
# Zatanna          good
# Zoom              bad
# Name: alignment, Length: 537, dtype: category
# Categories (4, object): ['-', 'bad', 'good', 'neutral']

# %%
hero['alignment'] == 'bad'
# Out:
# name
# A-Bomb           False
# Abomination       True
# Abraxas           True
# Absorbing Man     True
# Agent Bob        False
#                  ...
# Wildfire         False
# Wonder Girl      False
# Wonder Woman     False
# Zatanna          False
# Zoom              True
# Name: alignment, Length: 537, dtype: bool

# %%
hero.loc[hero['alignment'] == 'bad']
# Out:
#                gender eye color               race hair color  height  \
# name
# Abomination      Male     green  Human / Radiation    No Hair     203
# Abraxas          Male      blue      Cosmic Entity      Black     -99
# Absorbing Man    Male      blue              Human    No Hair     193
# Air-Walker       Male      blue                  -      White     188
# Ajax             Male     brown             Cyborg      Black     193
# ...               ...       ...                ...        ...     ...
# Swamp Thing      Male       red      God / Eternal    No Hair     -99
# Trigon           Male    yellow      God / Eternal      Black     -99
# Warp             Male     brown                  -      Black     173
# White Canary   Female     brown              Human      Black     -99
# Zoom             Male       red                  -      Brown     185
#
#                    publisher alignment  weight     hero names  agility  ...  \
# ...

# %%
mask = hero['alignment'] == 'bad'

# %%
mask.values
# Out:
# array([False,  True,  True,  True, False, False,  True,  True,  True,
#        False, False, False,  True, False, False, False,  True, False,
#        False,  True, False, False, False, False, False,  True, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False,  True,  True, False,  True, False, False, False,
#         True, False, False,  True,  True, False, False, False, False,
#         True,  True,  True,  True,  True, False,  True, False, False,
#        False,  True, False, False,  True, False, False, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#        False,  True,  True,  True, False, False,  True,  True, False,
#         True,  True, False, False,  True,  True,  True,  True, False,
# ...

# %%
hero.iloc[mask.values]
# Out:
#                gender eye color               race hair color  height  \
# name
# Abomination      Male     green  Human / Radiation    No Hair     203
# Abraxas          Male      blue      Cosmic Entity      Black     -99
# Absorbing Man    Male      blue              Human    No Hair     193
# Air-Walker       Male      blue                  -      White     188
# Ajax             Male     brown             Cyborg      Black     193
# ...               ...       ...                ...        ...     ...
# Swamp Thing      Male       red      God / Eternal    No Hair     -99
# Trigon           Male    yellow      God / Eternal      Black     -99
# Warp             Male     brown                  -      Black     173
# White Canary   Female     brown              Human      Black     -99
# Zoom             Male       red                  -      Brown     185
#
#                    publisher alignment  weight     hero names  agility  ...  \
# ...

# %%
hero.to_pickle('hero_5.pkl')
