# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero.pkl')

# %%
hero
# Out:
#               name  gender eye color               race hair color  height  \
# 0           A-Bomb    Male    yellow              Human    No Hair     203
# 1      Abomination    Male     green  Human / Radiation    No Hair     203
# 2          Abraxas    Male      blue      Cosmic Entity      Black     -99
# 3    Absorbing Man    Male      blue              Human    No Hair     193
# 4        Agent Bob    Male     brown              Human      Brown     178
# ..             ...     ...       ...                ...        ...     ...
# 532       Wildfire    Male         -                  -          -     -99
# 533    Wonder Girl  Female      blue           Demi-God      Blond     165
# 534   Wonder Woman  Female      blue             Amazon      Black     183
# 535        Zatanna  Female      blue              Human      Black     170
# 536           Zoom    Male       red                  -      Brown     185
#
# ...

# %%
type(hero['name'])
# Out:
# pandas.core.series.Series

# %%
hero['name'].head()
# Out:
# 0           A-Bomb
# 1      Abomination
# 2          Abraxas
# 3    Absorbing Man
# 4        Agent Bob
# Name: name, dtype: string

# %%
hero['name'].shape
# Out:
# (537,)

# %%
hero.height
# Out:
# 0      203
# 1      203
# 2      -99
# 3      193
# 4      178
#       ...
# 532    -99
# 533    165
# 534    183
# 535    170
# 536    185
# Name: height, Length: 537, dtype: int64

# %%
# hero.hero name => it remains errors
hero['hero names']
# Out:
# 0             A-Bomb
# 1        Abomination
# 2            Abraxas
# 3      Absorbing Man
# 4          Agent Bob
#            ...
# 532         Wildfire
# 533      Wonder Girl
# 534     Wonder Woman
# 535          Zatanna
# 536             Zoom
# Name: hero names, Length: 537, dtype: string

# %%
hero[['name','weight','height']]
# Out:
#               name  weight  height
# 0           A-Bomb   441.0     203
# 1      Abomination   441.0     203
# 2          Abraxas   -99.0     -99
# 3    Absorbing Man   122.0     193
# 4        Agent Bob    81.0     178
# ..             ...     ...     ...
# 532       Wildfire     NaN     -99
# 533    Wonder Girl    51.0     165
# 534   Wonder Woman    74.0     183
# 535        Zatanna    57.0     170
# 536           Zoom    81.0     185
#
# [537 rows x 3 columns]

# %%
type(hero[['name','weight','height']])
# Out:
# pandas.core.frame.DataFrame

# %%
hero.select_dtypes(include='number')
# Out:
#      height  weight
# 0       203   441.0
# 1       203   441.0
# 2       -99   -99.0
# 3       193   122.0
# 4       178    81.0
# ..      ...     ...
# 532     -99     NaN
# 533     165    51.0
# 534     183    74.0
# 535     170    57.0
# 536     185    81.0
#
# [537 rows x 2 columns]

# %%
hero.select_dtypes(include=['int64'])
# Out:
#      height
# 0       203
# 1       203
# 2       -99
# 3       193
# 4       178
# ..      ...
# 532     -99
# 533     165
# 534     183
# 535     170
# 536     185
#
# [537 rows x 1 columns]

# %%
hero.select_dtypes(include=['float64'])
# Out:
#      weight
# 0     441.0
# 1     441.0
# 2     -99.0
# 3     122.0
# 4      81.0
# ..      ...
# 532     NaN
# 533    51.0
# 534    74.0
# 535    57.0
# 536    81.0
#
# [537 rows x 1 columns]

# %%
hero.select_dtypes(exclude='number')
# Out:
#               name  gender eye color               race hair color  \
# 0           A-Bomb    Male    yellow              Human    No Hair
# 1      Abomination    Male     green  Human / Radiation    No Hair
# 2          Abraxas    Male      blue      Cosmic Entity      Black
# 3    Absorbing Man    Male      blue              Human    No Hair
# 4        Agent Bob    Male     brown              Human      Brown
# ..             ...     ...       ...                ...        ...
# 532       Wildfire    Male         -                  -          -
# 533    Wonder Girl  Female      blue           Demi-God      Blond
# 534   Wonder Woman  Female      blue             Amazon      Black
# 535        Zatanna  Female      blue              Human      Black
# 536           Zoom    Male       red                  -      Brown
#
#          publisher alignment     hero names  agility  accelerated healing  \
# 0    Marvel Comics      good         A-Bomb    False                 True
# ...

# %%
hero.select_dtypes(include=['number','bool','category'])
# Out:
#      gender  height alignment  weight  agility  accelerated healing  \
# 0      Male     203      good   441.0    False                 True
# 1      Male     203       bad   441.0    False                 True
# 2      Male     -99       bad   -99.0    False                False
# 3      Male     193       bad   122.0    False                False
# 4      Male     178      good    81.0    False                False
# ..      ...     ...       ...     ...      ...                  ...
# 532    Male     -99      good     NaN    False                False
# 533  Female     165      good    51.0     True                False
# 534  Female     183      good    74.0    False                 True
# 535  Female     170      good    57.0    False                False
# 536    Male     185       bad    81.0    False                False
#
#      lantern power ring  dimensional awareness  cold resistance  durability  \
# ...

# %%
hero.select_dtypes(include=['number','bool','category']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 537 entries, 0 to 536
# Columns: 171 entries, gender to omniscient
# dtypes: bool(167), category(2), float64(1), int64(1)
# memory usage: 101.5 KB

# %%
hero.to_pickle('hero_4.pkl')
