# %% [markdown]
# # Exporting Data

# %% [markdown]
# <img src="export_data.jpg" style="width:350px;height:220px"/>

# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
marvel_hero = pd.read_excel('superhero_info.xlsx',sheet_name='Marvel Comics')
dc_hero = pd.read_excel('superhero_info.xlsx',sheet_name='DC Comics')

# %%
hero_dtype = {'name':'string',
              'Gender': 'category',
              'Eye Color': 'string',
              'Race': 'string',
              'Hair Color': 'string',
              'Publisher': 'string',
              'Alignment': 'category'
              }

# %%
marvel_hero_newDtype = pd.read_excel('superhero_info.xlsx',sheet_name='Marvel Comics',dtype=hero_dtype)

# %%
marvel_hero_newDtype.to_excel('Marvel Hero corrected dtype.xlsx')

# %%
marvel_hero_newDtype.to_excel('Marvel Hero corrected dtype_noIndex.xlsx',index=False)

# %%
marvel_hero_newDtype.to_pickle('Marvel.pkl')

# %% [markdown]
# ## Load DC

# %%
dc_hero = pd.read_excel('superhero_info.xlsx',sheet_name='DC Comics',dtype=hero_dtype)

# %%
dc_hero_cdtype = dc_hero.to_csv('DC Hero cdtype.csv',index=False)

# %%
dc_hero_csv = pd.read_csv('DC Hero cdtype.csv')

# %%
dc_hero_csv
# Out:
#                   name  Gender Eye color      Race Hair color  Height  \
# 0             Abin Sur    Male      blue   Ungaran    No Hair     185
# 1         Adam Strange    Male      blue     Human      Blond     185
# 2           Alan Scott    Male      blue         -      Blond     180
# 3    Alfred Pennyworth    Male      blue     Human      Black     178
# 4                Amazo    Male       red   Android          -     257
# ..                 ...     ...       ...       ...        ...     ...
# 210           Wildfire    Male         -         -          -     -99
# 211        Wonder Girl  Female      blue  Demi-God      Blond     165
# 212       Wonder Woman  Female      blue    Amazon      Black     183
# 213            Zatanna  Female      blue     Human      Black     170
# 214               Zoom    Male       red         -      Brown     185
#
#      Publisher Alignment  Weight
# 0    DC Comics      good    90.0
# 1    DC Comics      good    88.0
# ...

# %%
dc_hero_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        215 non-null    object
#  1   Gender      215 non-null    object
#  2   Eye color   215 non-null    object
#  3   Race        215 non-null    object
#  4   Hair color  215 non-null    object
#  5   Height      215 non-null    int64
#  6   Publisher   215 non-null    object
#  7   Alignment   215 non-null    object
#  8   Weight      144 non-null    float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 15.2+ KB

# %%
dc_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        215 non-null    string
#  1   Gender      215 non-null    category
#  2   Eye color   215 non-null    object
#  3   Race        215 non-null    string
#  4   Hair color  215 non-null    object
#  5   Height      215 non-null    int64
#  6   Publisher   215 non-null    string
#  7   Alignment   215 non-null    category
#  8   Weight      144 non-null    float64
# dtypes: category(2), float64(1), int64(1), object(2), string(3)
# memory usage: 12.6+ KB

# %%
marvel_hero_pkl = pd.read_pickle('Marvel.pkl')

# %%
marvel_hero_pkl
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1        Abomination    Male     green  Human / Radiation           No Hair
# 2            Abraxas    Male      blue      Cosmic Entity             Black
# 3      Absorbing Man    Male      blue              Human           No Hair
# 4           Agent 13  Female      blue                  -             Blond
# ..               ...     ...       ...                ...               ...
# 383            X-Man    Male      blue                  -             Brown
# 384      Yellow Claw    Male      blue                  -           No Hair
# 385     Yellowjacket    Male      blue              Human             Blond
# 386  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 387             Ymir    Male     white        Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight
# ...

# %%
marvel_hero_pkl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        388 non-null    string
#  1   Gender      388 non-null    category
#  2   Eye color   388 non-null    object
#  3   Race        388 non-null    string
#  4   Hair color  388 non-null    object
#  5   Height      388 non-null    int64
#  6   Publisher   388 non-null    string
#  7   Alignment   388 non-null    category
#  8   Weight      388 non-null    int64
# dtypes: category(2), int64(2), object(2), string(3)
# memory usage: 22.4+ KB

# %%
marvel_hero = pd.read_excel('superhero_info.xlsx',sheet_name='Marvel Comics',dtype=hero_dtype)
dc_hero = pd.read_excel('superhero_info.xlsx',sheet_name='DC Comics',dtype=hero_dtype)

# %%
marvel_hero.to_pickle('Marvel Hero.pkl')
dc_hero.to_pickle('DC Hero.pkl')
